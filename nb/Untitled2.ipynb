# %%
from scipy.misc import imread
from scipy.misc import imresize
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
im=imread('../P01_13/P01_13/frame_0000000001.jpg')
plt.imshow(im)

# %%
img = im
y,x, z = img.shape
startx = x//2-(256//2)
starty = y//2-(256//2)    
print(startx, starty)
# Out:
# 100 0

# %%
def crop_center(img,cropx,cropy):
    y,x, z = img.shape
    startx = x//2-(cropx//2)
    starty = y//2-(cropy//2)    
    return img[starty:starty+cropy,startx:startx+cropx, :]

# %%
#plt.imshow(imresize(im, (128, 128, 3)))
plt.imshow(imresize(im[:, 100:356, :], (64, 64, 3)))
